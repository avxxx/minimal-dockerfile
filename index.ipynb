# %%
from scipy.stats import norm
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
rvs = norm.rvs(size=5000)

plt.figure(figsize=(8, 6))
sns.distplot(rvs)
plt.grid()
plt.show()
